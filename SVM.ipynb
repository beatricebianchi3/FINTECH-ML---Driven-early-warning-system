# %% [markdown]
# ### SUPPORT VECTOR MACHINE
#
# The primary goal of OneClassSVM is to find a decision function that describes the regions where the training data lies. It tries to separate the normal data points from the rest of the feature space. During the training phase, the algorithm fits a boundary around the data points in such a way that most of the data points lie within this boundary. This boundary is determined by the support vectors, which are the critical data points that define the shape and size of the decision boundary.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


# import the third page of FinancialM
df= pd.read_excel('FinancialMarketData.xlsx', sheet_name=2)

# save in y the output (market crashes equal to 1)
y = df.iloc[:, 0]

# drop the first column (output), drop the second column (dates)
df.drop(df.columns[0], axis=1, inplace=True)
df.drop(df.columns[0], axis=1, inplace=True)

df.head()
# Out:
#    XAU BGNL  ECSURPUS  BDIY     CRY     DXY     JPY     GBP    Cl1    VIX  \
# 0    283.25     0.077  1388  157.26  100.56  105.86  1.6460  25.77  22.50
# 1    287.65     0.043  1405  165.01  101.86  105.47  1.6383  28.85  21.50
# 2    287.15     0.135  1368  167.24  102.41  106.04  1.6496  28.28  23.02
# 3    282.75     0.191  1311  166.85  104.92  107.85  1.6106  28.22  23.45
# 4    298.40     0.312  1277  165.43  104.22  109.30  1.6108  28.02  21.25
#
#    USGG30YR  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS    MXEU     MXJP  \
# 0     6.671  ...  116.4635  230.5267  123.7616  1416.12  127.75   990.59
# 1     6.747  ...  117.2674  231.3770  123.7616  1428.79  129.50   993.98
# 2     6.634  ...  117.9946  232.3895  123.7616  1385.93  126.48   974.83
# 3     6.423  ...  120.5100  231.9417  122.3281  1385.31  129.19  1007.12
# 4     6.231  ...  118.7914  237.8117  122.3281  1411.95  134.67  1034.58
#
#      MXBR    MXRU    MXIN   MXCN
# 0  856.76  224.33  217.34  34.30
# ...

# %%
# check for nan values
nan_column = df.isna().sum()
print("Number of NaN in each column:")
print(nan_column)

# drop nan values
df = df.dropna()
print("\nDataFrame without rows with NaN:")
print(df)
# Out:
# Number of NaN in each column:
# XAU BGNL     0
# ECSURPUS     0
# BDIY         0
# CRY          0
# DXY          0
# JPY          0
# GBP          0
# Cl1          0
# VIX          0
# USGG30YR     0
# GT10         0
# USGG2YR      0
# USGG3M       0
# US0001M      0
# GTDEM30Y     0
# GTDEM10Y     0
# GTDEM2Y      0
# EONIA        0
# GTITL30YR    0
# GTITL10YR    0
# GTITL2YR     0
# GTJPY30YR    0
# GTJPY10YR    0
# GTJPY2YR     0
# GTGBP30Y     0
# GTGBP20Y     0
# GTGBP2Y      0
# LUMSTRUU     0
# LMBITR       0
# LUACTRUU     0
# LF98TRUU     0
# LG30TRUU     0
# LP01TREU     0
# EMUSTRUU     0
# LF94TRUU     0
# MXUS         0
# MXEU         0
# MXJP         0
# MXBR         0
# MXRU         0
# MXIN         0
# MXCN         0
# dtype: int64
#
# DataFrame without rows with NaN:
#       XAU BGNL  ECSURPUS  BDIY       CRY      DXY     JPY     GBP    Cl1  \
# 0       283.25     0.077  1388  157.2600  100.560  105.86  1.6460  25.77
# ...

# %%
# standard scaler
scaler = StandardScaler()
df_standardized = scaler.fit_transform(df)
column_names = df.columns
column_names = column_names.tolist()

# create the dataframe for the standardized values
df_standardized_pd = pd.DataFrame(df_standardized, columns=column_names)
df_standardized_pd
# Out:
#       XAU BGNL  ECSURPUS      BDIY       CRY       DXY       JPY       GBP  \
# 0    -1.424377  0.116941 -0.432277 -1.289246  0.846232 -0.058102  0.359879
# 1    -1.415478  0.019602 -0.423848 -1.175689  0.960528 -0.088487  0.323600
# 2    -1.416489  0.282989 -0.442193 -1.143014  1.008884 -0.044078  0.376841
# 3    -1.425389  0.443312 -0.470454 -1.148728  1.229563  0.096943  0.193090
# 4    -1.393734  0.789723 -0.487312 -1.169535  1.168019  0.209916  0.194033
# ...        ...       ...       ...       ...       ...       ...       ...
# 1106  1.497764  0.867021  0.005523 -0.890078  0.123178  0.164727 -0.912241
# 1107  1.412004  0.763956 -0.077773 -0.884629  0.207669  0.287049 -0.931558
# 1108  1.528751  1.156174 -0.083227 -0.870486  0.123090  0.255105 -0.883029
# 1109  1.527558  1.233472 -0.059428 -0.836822  0.080624  0.201346 -0.923077
# 1110  1.602457  1.305045  0.085348 -0.753790  0.018641  0.115642 -0.822250
#
# ...

# %%
# split the dataset in training (80%) and test (20%) sets
X_train_temp, X_test, y_train_temp, y_test = train_test_split(df_standardized_pd, y, test_size=0.2, random_state=41)

# split the temp dataset in training (75%) e validation (25%)
X_train, X_val, y_train, y_val = train_test_split(X_train_temp, y_train_temp, test_size=0.25, random_state=41)

print("Number of instances in training set:", df_standardized_pd.shape[0])
print("Number of instances in training set:", X_train.shape[0])
print("Number of instances in validation set:", X_val.shape[0])
print("Number of instances in test set:", X_test.shape[0])
# Out:
# Number of instances in training set: 1111
# Number of instances in training set: 666
# Number of instances in validation set: 222
# Number of instances in test set: 223

# %% [markdown]
# ### Buckets for the covariates

# %%
# create four buckets of covariates with respet to prior knowledge
bond_train = X_train.iloc[:, 9:35]
equity_train = X_train.iloc[:, 35:42]
commodities_train = X_train.iloc[:, [0,3,7]]
indexes_train = X_train.iloc[:, [1,2,4,5,6,8]]

# print the column in each bucket to check them
print("Bonds: ", bond_train.columns.tolist())
print("Equity: ", equity_train.columns.tolist())
print("Commodities: ", commodities_train.columns.tolist())
print("Indexes: ", indexes_train.columns.tolist())
# Out:
# Bonds:  ['USGG30YR', 'GT10', 'USGG2YR', 'USGG3M', 'US0001M', 'GTDEM30Y', 'GTDEM10Y', 'GTDEM2Y', 'EONIA', 'GTITL30YR', 'GTITL10YR', 'GTITL2YR', 'GTJPY30YR', 'GTJPY10YR', 'GTJPY2YR', 'GTGBP30Y', 'GTGBP20Y', 'GTGBP2Y', 'LUMSTRUU', 'LMBITR', 'LUACTRUU', 'LF98TRUU', 'LG30TRUU', 'LP01TREU', 'EMUSTRUU', 'LF94TRUU']
# Equity:  ['MXUS', 'MXEU', 'MXJP', 'MXBR', 'MXRU', 'MXIN', 'MXCN']
# Commodities:  ['XAU BGNL', 'CRY', 'Cl1']
# Indexes:  ['ECSURPUS', 'BDIY', 'DXY', 'JPY', 'GBP', 'VIX']

# %%
bond_val = X_val.iloc[:, 9:35]
equity_val = X_val.iloc[:, 35:42]
commodities_val = X_val.iloc[:, [0,3,7]]
indexes_val = X_val.iloc[:, [1,2,4,5,6,8]]

# %%
bond_test = X_test.iloc[:, 9:35]
equity_test = X_test.iloc[:, 35:42]
commodities_test = X_test.iloc[:, [0,3,7]]
indexes_test = X_test.iloc[:, [1,2,4,5,6,8]]

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import OneClassSVM
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %% [markdown]
# We perform a grid search to find the best model parameters using accuracy as the scoring metric, we tune the kernel, the nu parameter that indicates the probability of outliers in the dataset, gamma and coef0.

# %%
# parameters to test 
parametri = {'kernel': ['linear','poly', 'rbf', 'sigmoid'],
             'nu': [0.1, 0.15, 0.2],
             'gamma': [0.001, 0.1, 1, 10],
             'coef0': [0.05, 0.5, 1.0]}

# create the model 
model_bond = OneClassSVM()

# create an istance GridSearchCV with recall as metric 
grid_search = GridSearchCV(model_bond, parametri, cv=5, scoring='accuracy')

# find the best parameters
grid_search.fit(bond_train, y_train)
print("Best parameters:", grid_search.best_params_)

# implement the model sing the best parameters
model_bond = grid_search.best_estimator_

# show the recall of the model with best parameters
predictions = model_bond.predict(bond_train)
prediction_transformed = [1 if pred == -1 else 0 for pred in predictions]
accuracy = accuracy_score(y_train, prediction_transformed)
print("Best accuracy:", accuracy)
# Out:
# Best parameters: {'coef0': 0.05, 'gamma': 0.1, 'kernel': 'sigmoid', 'nu': 0.1}
# Best accuracy: 0.7102102102102102

# %%
# create the model
model_bond = OneClassSVM(kernel='sigmoid', nu=0.1, gamma=0.1, coef0=0.05)

# fit the model con the training set
model_bond.fit(bond_train)
# evaluate the model on the validation set used as test set before the ensemble method
prediction_bond = model_bond.predict(bond_val)
# transformed the prediction_bond to compare with the real values of the output
prediction_transformed_bond = [1 if pred == -1 else 0 for pred in prediction_bond]

report=classification_report(y_val, prediction_transformed_bond)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.15      0.26       175
#            1       0.24      1.00      0.39        47
#
#     accuracy                           0.33       222
#    macro avg       0.62      0.57      0.32       222
# weighted avg       0.84      0.33      0.29       222

# %%
# parameters to test 
parametri = {'kernel': ['linear','poly', 'rbf', 'sigmoid'],
             'nu': [0.1, 0.15, 0.2],
             'gamma': [0.001, 0.1, 1, 10],
             'coef0': [0.05, 0.5, 1.0]}

# create the model 
model_equity = OneClassSVM()

# create an istance GridSearchCV with recall as metric 
grid_search = GridSearchCV(model_equity, parametri, cv=5, scoring='accuracy')

# find the best parameters
grid_search.fit(equity_train, y_train)
print("Best parameters:", grid_search.best_params_)

# implement the model sing the best parameters
model_equity = grid_search.best_estimator_

# show the recall of the model with best parameters
predictions = model_equity.predict(equity_train)
prediction_transformed = [1 if pred == -1 else 0 for pred in predictions]
accuracy = accuracy_score(y_train, prediction_transformed)
print("Best accuracy:", accuracy)
# Out:
# Best parameters: {'coef0': 0.05, 'gamma': 0.1, 'kernel': 'poly', 'nu': 0.1}
# Best recall : 0.6996996996996997

# %%
# create the model
model_equity = OneClassSVM(kernel='poly', nu=0.1, gamma=0.1, coef0=0.05)

# fit the model con the training set
model_equity.fit(equity_train)
# evaluate the model on the validation set used as test set before the ensemble method
prediction_equity = model_equity.predict(equity_val)
# transformed the prediction_bond to compare with the real values of the output
prediction_transformed_equity = [1 if pred == -1 else 0 for pred in prediction_equity]

report=classification_report(y_val, prediction_transformed_equity)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.80       175
#            1       0.03      0.02      0.03        47
#
#     accuracy                           0.66       222
#    macro avg       0.40      0.43      0.41       222
# weighted avg       0.61      0.66      0.63       222

# %%
# parameters to test 
parametri = {'kernel': ['linear','poly', 'rbf', 'sigmoid'],
             'nu': [0.1, 0.15, 0.2],
             'gamma': [0.001, 0.1, 1, 10],
             'coef0': [0.05, 0.5, 1.0]}

# create the model 
model_commodities = OneClassSVM()

# create an istance GridSearchCV with recall as metric 
grid_search = GridSearchCV(model_commodities, parametri, cv=5, scoring='accuracy')

# find the best parameters
grid_search.fit(commodities_train, y_train)
print("Best parameters:", grid_search.best_params_)

# implement the model sing the best parameters
model_commodities = grid_search.best_estimator_

# show the recall of the model with best parameters
predictions = model_commodities.predict(commodities_train)
prediction_transformed = [1 if pred == -1 else 0 for pred in predictions]
accuracy = accuracy_score(y_train, prediction_transformed)
print("Best recall :", accuracy)
# Out:
# Best parameters: {'coef0': 1.0, 'gamma': 10, 'kernel': 'sigmoid', 'nu': 0.2}
# Best recall : 0.6471471471471472

# %%
# create the model
model_commodities = OneClassSVM(kernel='sigmoid', nu=0.2, gamma=10, coef0=1.0)

# fit the model con the training set
model_commodities.fit(commodities_train)
# evaluate the model on the validation set used as test set before the ensemble method
prediction_commodities = model_commodities.predict(commodities_val)
# transformed the prediction_bond to compare with the real values of the output
prediction_transformed_commodities = [1 if pred == -1 else 0 for pred in prediction_commodities]

report=classification_report(y_val, prediction_transformed_commodities)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79       175
#            1       0.11      0.09      0.10        47
#
#     accuracy                           0.66       222
#    macro avg       0.44      0.45      0.44       222
# weighted avg       0.63      0.66      0.64       222

# %%
# parameters to test 
parametri = {'kernel': ['linear','poly', 'rbf', 'sigmoid'],
             'nu': [0.1, 0.15, 0.2],
             'gamma': [0.001, 0.1, 1, 10],
             'coef0': [0.05, 0.5, 1.0]}

# create the model 
model_indexes = OneClassSVM()

# create an istance GridSearchCV with recall as metric 
grid_search = GridSearchCV(model_indexes, parametri, cv=5, scoring='accuracy')

# find the best parameters
grid_search.fit(indexes_train, y_train)
print("Best parameters:", grid_search.best_params_)

# implement the model sing the best parameters
model_indexes = grid_search.best_estimator_

# show the recall of the model with best parameters
predictions = model_indexes.predict(indexes_train)
prediction_transformed = [1 if pred == -1 else 0 for pred in predictions]
accuracy = accuracy_score(y_train, prediction_transformed)
print("Best recall :", accuracy)
# Out:
# Best parameters: {'coef0': 1.0, 'gamma': 1, 'kernel': 'poly', 'nu': 0.1}
# Best recall : 0.6921921921921922

# %%
# create the model
model_indexes = OneClassSVM(kernel='poly', nu=0.1, gamma=1, coef0=1)

# fit the model con the training set
model_indexes.fit(indexes_train)
# evaluate the model on the validation set used as test set before the ensemble method
prediction_indexes = model_indexes.predict(indexes_val)
# transformed the prediction_bond to compare with the real values of the output
prediction_transformed_indexes = [1 if pred == -1 else 0 for pred in prediction_indexes]

report=classification_report(y_val, prediction_transformed_indexes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81       175
#            1       0.04      0.02      0.03        47
#
#     accuracy                           0.68       222
#    macro avg       0.40      0.44      0.42       222
# weighted avg       0.61      0.68      0.64       222

# %% [markdown]
# We do not choose this model since, by maximizing the accuracy during parameters' tuning, it de-emphasized the importance of recall and precision of crash detections, which are crucial in our study. Accuracy as a metric can mask poor performance in identifying crashes, leading to fewer detected crashes and potentially overlooking critical incidents that our analysis aims to capture and address.
